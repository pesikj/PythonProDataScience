# %% [markdown]
# # Řešení kvízu z jedenácté lekce
#
# ## Část 1
#
# ### Otázka 1
#
# Máme seznam X, ve kterém jsou dva řetězce:
#
# ```py
# X = ["I believe I can fly",  "I believe I can touch the sky"]
# Jak se jmenuje postup pro NLP, který z těchto dvou řetězců vytvořil tabulku níže?
# ```
#
# ![1.png](1.png)
#
# *TF-IDF Vectorizer*
#
# ### Otázka 2
#
# Tabulka níže je vytvořená ze stejných dvou řetězců, tj.
# ```py
# X = ["I believe I can fly",  "I believe I can touch the sky"]
# ```
#
# Pro její vytvoření byla použitá stejná transformace jako v předchozí otázce, pouze byl použit jeden parametr navíc. Jaký je název tohoto parametru? A jaká byla jeho hodnota? (Stejnou hodnotu jsme používali i v lekci.)
#
# ![2.png](2.png)
#
# *Název je stop_words, hodnotu jsme nastavili na english.*
#
# ### Otázka 3
#
# Když se podíváme na jednotlivé řádky, je hodnota ve sloupci u slova believe vždy nižší než hodnota u ostatních slov (pokud ignorujeme slova, která se v řetězci nevyskytují a tím pádem mají v daném řádkud hodnotu 0). Proč tomu tak je?
#
# ![2.png](2.png)
#
# *TFIDF zohledňuje jak často se proměnná objevuje v dokumentu/a v kolika dokumentech se proměnná objevuje alespoň jednou. Slovo believe se vyskytuje v textu několikrát a proto je jeho hodnota nižší. Ostatní slova se vyskytují méně často.*
#
# ### Otázka 4
#
# Poslední otázka k tabulce níže. Když porovnáme slova fly, sky a touch, mají i ona různé hodnoty. Fly má vyšší hodnotu než sky nebo touch. Proč tomu tak je?
#
# ![1.png](1.png)
#
# *Použitý algoritmus zohledňuje délku řetězce (dokumentu). Čím je řetězec (dokument) delší, tím menší hodnota je u každého slova.*
#
# ### Otázka 5
#
# Nyní máme ze stejných dvou řetězců vytvořenou tabulku níže. Jak jsme tabulku získali?
#
# ![3.png](3.png)
#
# *Využili jsme jiný postup, konkrétně Count Vectorizer.*
#
# ## Část 2
#
# Stáhni si data ze souboru spam_utf8.csv, který obsahuje SMS zprávy posílané v angličtině. O každé zprávě víme, jestli je to legitimní zpráva nebo spam.
# Data obsahují dva sloupce:
# - v1 - označení, zda jde o legitimní zprávu (ham) nebo spam (spam)
# - v2 - text SMS zprávy.
#
# ### Otázka 6
#
# Chceme vytvořit model, který na základě slov, které zpráva obsahuje, odhadne, zda jde o spam. Jaké algoritmy bychom mohli použít?
#
# *Algoritmy supervised learning (např. KNN, SVM, rozhodovací strom)*
#
# ### Otázka 7
#
# Co je pravda o následujícím kódu? (Vyber 3 možnosti.)
#
# ```py
# data = pd.read_csv("spam_utf8.csv")
# X = data["v2"]
# y = data["v1"]
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
#
# vec = TfidfVectorizer()
# X_train = vec.fit_transform(X_train)
# X_test = vec.transform(X_test)
#
# clf = KNeighborsClassifier(n_neighbors=15)
# clf.fit(X_train, y_train)
# y_pred = clf.predict(X_test)
#
# accuracy_score(y_test, y_pred)
# ```
#
# * *Používá algoritmus KNN a uvažuje 15 nejbližších sousedů,*
# * *Používá algoritmus TF-IDF a ponechává stop words v datech,*
# * *Na konci algoritmus vypíše, kolik zpráv bylo zařazeno do správné skupiny.*
#
# ### Otázka 8
#
# Napiš příkaz, kterým ověříš, nakolik je dataset vyvážený (balanced).
#
# ```py
# data["v1"].value_counts()
# ```
#
# ### Otázka 9
#
# ```py
# V rámci předchozí otázky jsi pravděpodobně došel (došla) k závěru, že dataset je poměrně nevyvážený, protože legitimních zpráv je tam mnohem více než spamu. Napiš příkaz, který vypočte hodnotu metriky balanced accuracy, která zohledňuje nevyváženost jednotlivých tříd. Je třeba využít funkci balanced_accuracy_score, která se importu ze stejného modulu jako accuracy_score a používá se úplně stejným způsobem.
#
# data = pd.read_csv("spam_utf8.csv")
# X = data["v2"]
# y = data["v1"]
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
#
# vec = TfidfVectorizer()
# X_train = vec.fit_transform(X_train)
# X_test = vec.transform(X_test)
#
# clf = KNeighborsClassifier(n_neighbors=15)
# clf.fit(X_train, y_train)
# y_pred = clf.predict(X_test)
# ```
#
# ```py
# balanced_accuracy_score(y_pred,y_test)
# ```
#
# ### Otázka 10
#
# Níže je matice záměn, která byla vygenerovaná z výsledků předchozího kódu. Které 2 tvrzení je správná?
#
# ![4.png](4.png)
#
# *45 spamovacích zpráv bylo chybně označeno jako legitimní., 2 spamovací zprávy byly chybně označeny jako legitimní.*

# %%
import pandas as pd

from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, balanced_accuracy_score
data = pd.read_csv("spam_utf8.csv")
X = data["v2"]
y = data["v1"]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

vec = TfidfVectorizer()
X_train = vec.fit_transform(X_train)
X_test = vec.transform(X_test)

clf = KNeighborsClassifier(n_neighbors=15)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
balanced_accuracy_score(y_pred,y_test)
# Out:
# 0.9716263262599469
