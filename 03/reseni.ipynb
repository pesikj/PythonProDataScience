# %%
import pandas
df = pandas.read_csv("half_marathon.csv")

df = df.sort_values(["Jmeno", "Rok zavodu"])
df["Cas zavodnika"] = pandas.to_datetime(df["Cas zavodnika"])
df["Cas zavodnika 2020"] = df.groupby("Jmeno")["Cas zavodnika"].shift(-1)
df = df.dropna()
df["Zmena"] = df["Cas zavodnika 2020"] - df["Cas zavodnika"]
df["Zmena"] = df["Zmena"].dt.total_seconds()
df["Zmena"].mean()
# Out:
# C:\Users\jirip\AppData\Local\Temp\ipykernel_17296\580763057.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Cas zavodnika"] = pandas.to_datetime(df["Cas zavodnika"])
# 583.7731958762887

# %%
# Bonus
df["Zmena Text"] = pandas.cut(df["Zmena"], bins=[float("-inf"), 0 , float("inf")], labels=["zlepsil se", "zhorsil se"])
df
# Out:
#      Unnamed: 0               Jmeno       Cas zavodnika  Rok zavodu
# 76           76      Aster Vladimír 2023-04-15 01:53:25        2019  \
# 231         231       Asterová Jana 2023-04-15 02:16:59        2019
# 101         101       Baborová Anna 2023-04-15 01:58:20        2019
# 132         132          Bambas Jan 2023-04-15 02:02:59        2019
# 324         324  Barochovská Andrea 2023-04-15 03:01:25        2019
# ..          ...                 ...                 ...         ...
# 30           30       Šulcová Jitka 2023-04-15 01:43:12        2019
# 278         278      Švarcová Petra 2023-04-15 02:27:45        2019
# 82           82        Švelch Rosťa 2023-04-15 01:54:58        2019
# 318         318        Žitková Jana 2023-04-15 02:45:54        2019
# 140         140       Žákovec Pavel 2023-04-15 02:03:36        2019
#
#      Cas zavodnika 2020   Zmena  Zmena Text
# 76  2023-04-15 02:00:19   414.0  zhorsil se
# 231 2023-04-15 02:30:01   782.0  zhorsil se
# 101 2023-04-15 01:52:25  -355.0  zlepsil se
# 132 2023-04-15 02:35:39  1960.0  zhorsil se
# 324 2023-04-15 02:50:05  -680.0  zlepsil se
# ..                  ...     ...         ...
# 30  2023-04-15 01:59:07   955.0  zhorsil se
# 278 2023-04-15 02:50:01  1336.0  zhorsil se
# 82  2023-04-15 01:55:11    13.0  zhorsil se
# 318 2023-04-15 02:42:48  -186.0  zlepsil se
# 140 2023-04-15 02:07:37   241.0  zhorsil se
#
# [97 rows x 7 columns]
