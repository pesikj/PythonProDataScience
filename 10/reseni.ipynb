# %%
import pandas as pd
from sklearn.metrics import jaccard_score
from scipy.spatial.distance import pdist, squareform

data = pd.read_csv("tmdb_5000_movies.csv")
data = data.set_index("title")
data.head()
# Out:
#                                              budget  gen_Action  \
# title
# Avatar                                    237000000         1.0
# Pirates of the Caribbean: At World's End  300000000         1.0
# Spectre                                   245000000         1.0
# The Dark Knight Rises                     250000000         1.0
# John Carter                               260000000         1.0
#
#                                           gen_Adventure  gen_Animation  \
# title
# Avatar                                              1.0            0.0
# Pirates of the Caribbean: At World's End            1.0            0.0
# Spectre                                             1.0            0.0
# The Dark Knight Rises                               0.0            0.0
# John Carter                                         1.0            0.0
#
#                                           gen_Comedy  gen_Crime  \
# title
# ...

# %%
data_genres = data.loc[:, "gen_Action":"gen_Western"]
data_genres.head()
# Out:
#                                           gen_Action  gen_Adventure  \
# title
# Avatar                                           1.0            1.0
# Pirates of the Caribbean: At World's End         1.0            1.0
# Spectre                                          1.0            1.0
# The Dark Knight Rises                            1.0            0.0
# John Carter                                      1.0            1.0
#
#                                           gen_Animation  gen_Comedy  \
# title
# Avatar                                              0.0         0.0
# Pirates of the Caribbean: At World's End            0.0         0.0
# Spectre                                             0.0         0.0
# The Dark Knight Rises                               0.0         0.0
# John Carter                                         0.0         0.0
#
#                                           gen_Crime  gen_Documentary  \
# title
# ...

# %%
data_genres.loc["The Fugitive"]
# Out:
# gen_Action             1.0
# gen_Adventure          1.0
# gen_Animation          0.0
# gen_Comedy             0.0
# gen_Crime              1.0
# gen_Documentary        0.0
# gen_Drama              0.0
# gen_Family             0.0
# gen_Fantasy            0.0
# gen_Foreign            0.0
# gen_History            0.0
# gen_Horror             0.0
# gen_Music              0.0
# gen_Mystery            1.0
# gen_Romance            0.0
# gen_Science Fiction    0.0
# gen_TV Movie           0.0
# gen_Thriller           1.0
# gen_War                0.0
# gen_Western            0.0
# Name: The Fugitive, dtype: float64

# %%
data.loc["Witness"]
# Out:
# budget                                                           12000000
# gen_Action                                                            0.0
# gen_Adventure                                                         0.0
# gen_Animation                                                         0.0
# gen_Comedy                                                            0.0
# gen_Crime                                                             1.0
# gen_Documentary                                                       0.0
# gen_Drama                                                             1.0
# gen_Family                                                            0.0
# gen_Fantasy                                                           0.0
# gen_Foreign                                                           0.0
# gen_History                                                           0.0
# gen_Horror                                                            0.0
# ...

# %%
data_genres.loc["Titanic"]
# Out:
# gen_Action             0.0
# gen_Adventure          0.0
# gen_Animation          0.0
# gen_Comedy             0.0
# gen_Crime              0.0
# gen_Documentary        0.0
# gen_Drama              1.0
# gen_Family             0.0
# gen_Fantasy            0.0
# gen_Foreign            0.0
# gen_History            0.0
# gen_Horror             0.0
# gen_Music              0.0
# gen_Mystery            0.0
# gen_Romance            1.0
# gen_Science Fiction    0.0
# gen_TV Movie           0.0
# gen_Thriller           1.0
# gen_War                0.0
# gen_Western            0.0
# Name: Titanic, dtype: float64

# %%
jaccard_score(data_genres.loc["The Fugitive"], data_genres.loc["Witness"])
# Out:
# 0.2857142857142857

# %%
jaccard_score(data_genres.loc["The Fugitive"], data_genres.loc["Titanic"])
# Out:
# 0.14285714285714285

# %%
from scipy.spatial.distance import pdist, squareform

jaccard_distances = pdist(data_genres, metric="jaccard")
jaccard_distances = squareform(jaccard_distances)
jaccard_distances = 1 - jaccard_distances

# %%
jaccard_distances = pd.DataFrame(jaccard_distances, index=data.index, columns=data.index)
jaccard_distances
# Out:
# title                                       Avatar  \
# title
# Avatar                                    1.000000
# Pirates of the Caribbean: At World's End  0.750000
# Spectre                                   0.400000
# The Dark Knight Rises                     0.142857
# John Carter                               0.750000
# ...                                            ...
# El Mariachi                               0.166667
# Newlyweds                                 0.000000
# Signed, Sealed, Delivered                 0.000000
# Shanghai Calling                          0.000000
# My Date with Drew                         0.000000
#
# title                                     Pirates of the Caribbean: At World's End  \
# title
# Avatar                                                                    0.750000
# Pirates of the Caribbean: At World's End                                  1.000000
# Spectre                                                                   0.500000
# ...

# %%
jaccard_distances["The Fugitive"].sort_values(ascending=False).head(20)
# Out:
# title
# The Losers                            1.000000
# The Fugitive                          1.000000
# Nancy Drew                            0.833333
# The Negotiator                        0.833333
# xXx: State of the Union               0.833333
# Now You See Me 2                      0.833333
# The Corruptor                         0.800000
# National Treasure                     0.800000
# The Long Kiss Goodnight               0.800000
# Switchback                            0.800000
# Sherlock Holmes: A Game of Shadows    0.800000
# The Jackal                            0.800000
# Whiteout                              0.800000
# Changing Lanes                        0.800000
# Into the Blue                         0.800000
# Ronin                                 0.800000
# Alex Cross                            0.800000
# A Lonely Place to Die                 0.800000
# Shaft                                 0.800000
# Quantum of Solace                     0.800000
# ...

# %%
import pandas as pd

data['release_date'] = pd.to_datetime(data['release_date'])
data['release_year'] = data['release_date'].dt.year

bins = [1979, 1989, 1999, 2009, 2019, 2029]
labels = ['1980s', '1990s', '2000s', '2010s', '2020s']

# Categorize the release years into decades
data['decade'] = pd.cut(data['release_year'], bins=bins, labels=labels)

# Display the DataFrame to verify the changes
data[['release_date', 'release_year', 'decade']].head(30)
# Out:
#                                             release_date  release_year decade
# title
# Avatar                                        2009-12-10        2009.0  2000s
# Pirates of the Caribbean: At World's End      2007-05-19        2007.0  2000s
# Spectre                                       2015-10-26        2015.0  2010s
# The Dark Knight Rises                         2012-07-16        2012.0  2010s
# John Carter                                   2012-03-07        2012.0  2010s
# Spider-Man 3                                  2007-05-01        2007.0  2000s
# Tangled                                       2010-11-24        2010.0  2010s
# Avengers: Age of Ultron                       2015-04-22        2015.0  2010s
# Harry Potter and the Half-Blood Prince        2009-07-07        2009.0  2000s
# Batman v Superman: Dawn of Justice            2016-03-23        2016.0  2010s
# Superman Returns                              2006-06-28        2006.0  2000s
# ...

# %%
jaccard_distances["decade"] = data["decade"]

# %%
decade = jaccard_distances.loc["The Fugitive", "decade"]
movies_from_decade = jaccard_distances[jaccard_distances["decade"] == decade]
movies_from_decade["The Fugitive"].sort_values(ascending=False).head(20)
# Out:
# title
# The Fugitive                       1.000000
# The Negotiator                     0.833333
# The River Wild                     0.800000
# The Corruptor                      0.800000
# Switchback                         0.800000
# Ronin                              0.800000
# The Jackal                         0.800000
# Assassins                          0.800000
# The Long Kiss Goodnight            0.800000
# Dick Tracy                         0.666667
# The Net                            0.666667
# The Limey                          0.666667
# The Adventures of Ford Fairlane    0.666667
# The Glimmer Man                    0.666667
# RoboCop 3                          0.666667
# Smilla's Sense of Snow             0.666667
# Lethal Weapon 4                    0.666667
# Lethal Weapon 3                    0.666667
# 8MM                                0.600000
# Se7en                              0.600000
# Name: The Fugitive, dtype: float64
